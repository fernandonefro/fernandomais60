# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandonefro/fernandomais60/blob/master/Limpar%20o%20banco%20de%20dados%20Tipo%20de%20Atendimento%20para%20a%20%C3%BAltima%20consulta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importar as bibliotecas necessárias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style()
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# importar o dataset COVID-19 para um DataaFrame

df = pd.read_csv('https://raw.githubusercontent.com/fernandonefro/geriatria/main/Ultimos%20365%20dias%2017-2-21.csv?token=ABO2W7KROYWSFUIQQVEAE7LAG6BBM', sep=";", encoding="latin1", decimal=",")

# %%
df.head()
# Out:
#          Empresa      Unidade  ...  Unnamed: 36 Unnamed: 37
# 0  Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 1  Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 2  Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 3  Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 4  Mais 60 Saúde  Barro Preto  ...          NaN         NaN
#
# [5 rows x 38 columns]

# %%
df.dtypes
# Out:
# Empresa                        object
# Unidade                        object
# IdentificadorDoAtendimento    float64
# Inicio                         object
# Ano                           float64
# Mês                           float64
# AnoMes                        float64
# Fim                           float64
# TempoEmMinutos                float64
# Ano2                          float64
# Mes                            object
# DiaDaSemana                    object
# Turno                          object
# Status                         object
# TipoDeAtendimento              object
# TipoDeAgendamento              object
# Profissional                   object
# Profissao                      object
# IdentificadorDoPaciente       float64
# Paciente                       object
# ultima_data                    object
# repetido                       object
# Cpf                            object
# DataDeNascimento              float64
# Idade                         float64
# ...

# %%
df.Inicio = pd.to_datetime(df.Inicio)

# %%
df.dtypes
# Out:
# Empresa                               object
# Unidade                               object
# IdentificadorDoAtendimento           float64
# Inicio                        datetime64[ns]
# Ano                                  float64
# Mês                                  float64
# AnoMes                               float64
# Fim                                  float64
# TempoEmMinutos                       float64
# Ano2                                 float64
# Mes                                   object
# DiaDaSemana                           object
# Turno                                 object
# Status                                object
# TipoDeAtendimento                     object
# TipoDeAgendamento                     object
# Profissional                          object
# Profissao                             object
# IdentificadorDoPaciente              float64
# Paciente                              object
# ultima_data                           object
# ...

# %%
df.sort_values('Inicio').drop_duplicates('Paciente',keep='last')
# Out:
#              Empresa      Unidade  ...  Unnamed: 36 Unnamed: 37
# 484    Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 2456   Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 3170   Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 3487   Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 2812   Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# ...              ...          ...  ...          ...         ...
# 5651   Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 10054  Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 1101   Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 7125   Mais 60 Saúde  Barro Preto  ...          NaN         NaN
# 17152            NaN          NaN  ...          NaN         NaN
#
# [4429 rows x 38 columns]

# %%
df.to_excel("output.xlsx")
