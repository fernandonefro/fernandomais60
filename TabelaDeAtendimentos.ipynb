# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandonefro/fernandomais60/blob/master/TabelaDeAtendimentos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/BANCO_RICARDO_atendimentos_de_2016_01_01_ateh_2021_02_17_em_2021_02_17_13_29_40.csv", sep=";")

# %%
df.head()
# Out:
#          Empresa      Unidade  ...   NumeroDaCarteira Ivcf
# 0  Mais 60 Saúde  Barro Preto  ...  00060501628456007  NaN
# 1  Mais 60 Saúde  Barro Preto  ...  00060502775971516  NaN
# 2  Mais 60 Saúde  Barro Preto  ...  00063627084602000  NaN
# 3  Mais 60 Saúde  Barro Preto  ...  00060500179393005  NaN
# 4  Mais 60 Saúde  Barro Preto  ...  00060501277870000  NaN
#
# [5 rows x 30 columns]

# %%
df['data_nova'] = df['Inicio'].str[0:9]

# %%
df.head()
# Out:
#          Empresa      Unidade  ...  Ivcf  data_nova
# 0  Mais 60 Saúde  Barro Preto  ...   NaN  2019-04-1
# 1  Mais 60 Saúde  Barro Preto  ...   NaN  2019-04-1
# 2  Mais 60 Saúde  Barro Preto  ...   NaN  2019-04-1
# 3  Mais 60 Saúde  Barro Preto  ...   NaN  2019-04-1
# 4  Mais 60 Saúde  Barro Preto  ...   NaN  2019-04-1
#
# [5 rows x 31 columns]

# %%
df.sort_values(by=['Paciente','data_nova'], inplace=True)

# %%
df.head()
# Out:
#              Empresa      Unidade  ...  Ivcf  data_nova
# 21290  Mais 60 Saúde  Barro Preto  ...   NaN  2019-07-1
# 21213  Mais 60 Saúde  Barro Preto  ...   NaN  2019-07-1
# 21250  Mais 60 Saúde  Barro Preto  ...   NaN  2019-07-1
# 23909  Mais 60 Saúde  Barro Preto  ...   NaN  2019-07-2
# 23637  Mais 60 Saúde  Barro Preto  ...   NaN  2019-07-2
#
# [5 rows x 31 columns]

# %%
# Try to create a second dataframe df2 from df with all columns except 'B' and D
MÉDICO(A)
df2 = df[df.Profissao != '']

# %%
df[df.Profissao == 'MÉDICO(A)']
# Out:
#               Empresa         Unidade  ...   NumeroDaCarteira  Ivcf
# 1658    Mais 60 Saúde     Barro Preto  ...  00060500373008006   NaN
# 1778    Mais 60 Saúde     Barro Preto  ...  00060501436259009   NaN
# 2335    Mais 60 Saúde     Barro Preto  ...  00060500150132017   NaN
# 2352    Mais 60 Saúde     Barro Preto  ...  00060500150132017   NaN
# 2353    Mais 60 Saúde     Barro Preto  ...  00064148004806913   NaN
# ...               ...             ...  ...                ...   ...
# 199024  Mais 60 Saúde     Barro Preto  ...                363  34.0
# 199030  Mais 60 Saúde     Barro Preto  ...  00066450438174005  17.0
# 199048  Mais 60 Saúde     Barro Preto  ...               1147  22.0
# 199067  Mais 60 Saúde  Santa Efigênia  ...  00060500996630006  29.0
# 199094  Mais 60 Saúde  Santa Efigênia  ...  00064957121599000  12.0
#
# [42962 rows x 30 columns]

# %%
df2 = df.query('Profissao =="MÉDICO(A)"')

# %%
df2.head()
# Out:
#             Empresa      Unidade  ...   NumeroDaCarteira Ivcf
# 1658  Mais 60 Saúde  Barro Preto  ...  00060500373008006  NaN
# 1778  Mais 60 Saúde  Barro Preto  ...  00060501436259009  NaN
# 2335  Mais 60 Saúde  Barro Preto  ...  00060500150132017  NaN
# 2352  Mais 60 Saúde  Barro Preto  ...  00060500150132017  NaN
# 2353  Mais 60 Saúde  Barro Preto  ...  00064148004806913  NaN
#
# [5 rows x 30 columns]

# %%
pivot2 = pd.pivot_table(df2, index='TipoDeAtendimento', values='Idade', aggfunc='count')
pivot2
# Out:
#                                      Idade
# TipoDeAtendimento
# ATENDIMENTO NO PRONTO CUIDAR            13
# CONTATO SEM SUCESSO                    843
# CONTATO TELEFÔNICO                       1
# ENCAMINHAMENTO                          28
# EVOLUÇÃO PRESENCIAL                  25284
# ONCOGERIATRIA - EVOLUÇÃO PRESENCIAL     82
# ORIENTAÇÃO MÉDICA                     6583
# PRESCRIÇÃO                            3617
# TELECONSULTA MÉDICA                   6288
# VISITA MÉDICA DOMICILIAR                 8
# VÍDEO CONSULTA MÉDICA                  215

# %%
df.drop(labels=None, axis=0, index=None, columns=None, level=None, inplace=False, errors='raise')
